# %%
import wwo_hist

# %%
from wwo_hist import retrieve_hist_data

# %%
import os
os.getcwd()
# Out:
# '/Users/IshaanShah'

# %%
os.chdir("/Users/IshaanShah/Desktop/weather_data")

# %%
frequency = 24
start_date = '01-JAN-2015'
end_date = '01-JAN-2021'
api_key = 'f29990ba8555456b97f102600213007'
location_list = ['california']
hist_weather_data = retrieve_hist_data(api_key,
                                location_list,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for california
#
#
# Currently retrieving data for california: from 2015-01-01 to 2015-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.958048
# Currently retrieving data for california: from 2015-02-01 to 2015-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:03.181236
# Currently retrieving data for california: from 2015-03-01 to 2015-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.667017
# Currently retrieving data for california: from 2015-04-01 to 2015-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.590848
# Currently retrieving data for california: from 2015-05-01 to 2015-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.236974
# Currently retrieving data for california: from 2015-06-01 to 2015-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:10.550809
# Currently retrieving data for california: from 2015-07-01 to 2015-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:11.982491
# Currently retrieving data for california: from 2015-08-01 to 2015-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:13.187357
# Currently retrieving data for california: from 2015-09-01 to 2015-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:14.461299
# Currently retrieving data for california: from 2015-10-01 to 2015-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:16.511101
# Currently retrieving data for california: from 2015-11-01 to 2015-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:18.043518
# Currently retrieving data for california: from 2015-12-01 to 2015-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:20.857743
# Currently retrieving data for california: from 2016-01-01 to 2016-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:22.418806
# Currently retrieving data for california: from 2016-02-01 to 2016-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:23.861100
# Currently retrieving data for california: from 2016-03-01 to 2016-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:25.134341
# Currently retrieving data for california: from 2016-04-01 to 2016-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:26.197366
# Currently retrieving data for california: from 2016-05-01 to 2016-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:27.744395
# Currently retrieving data for california: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:29.063929
# Currently retrieving data for california: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:30.423639
# Currently retrieving data for california: from 2016-08-01 to 2016-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:31.925888
# Currently retrieving data for california: from 2016-09-01 to 2016-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:33.297372
# Currently retrieving data for california: from 2016-10-01 to 2016-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:34.788130
# Currently retrieving data for california: from 2016-11-01 to 2016-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:36.702076
# Currently retrieving data for california: from 2016-12-01 to 2016-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:37.859078
# Currently retrieving data for california: from 2017-01-01 to 2017-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:39.884289
# Currently retrieving data for california: from 2017-02-01 to 2017-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:41.367894
# Currently retrieving data for california: from 2017-03-01 to 2017-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:42.698525
# Currently retrieving data for california: from 2017-04-01 to 2017-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:44.294058
# Currently retrieving data for california: from 2017-05-01 to 2017-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:45.796150
# Currently retrieving data for california: from 2017-06-01 to 2017-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:47.266731
# Currently retrieving data for california: from 2017-07-01 to 2017-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:49.114609
# Currently retrieving data for california: from 2017-08-01 to 2017-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:50.642523
# Currently retrieving data for california: from 2017-09-01 to 2017-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:52.029106
# Currently retrieving data for california: from 2017-10-01 to 2017-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:53.266344
# Currently retrieving data for california: from 2017-11-01 to 2017-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:54.730465
# Currently retrieving data for california: from 2017-12-01 to 2017-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:56.065373
# Currently retrieving data for california: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:57.400025
# Currently retrieving data for california: from 2018-02-01 to 2018-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:58.579966
# Currently retrieving data for california: from 2018-03-01 to 2018-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:00.223326
# Currently retrieving data for california: from 2018-04-01 to 2018-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:01.647688
# Currently retrieving data for california: from 2018-05-01 to 2018-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:03.197180
# Currently retrieving data for california: from 2018-06-01 to 2018-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:04.782338
# Currently retrieving data for california: from 2018-07-01 to 2018-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:06.023138
# Currently retrieving data for california: from 2018-08-01 to 2018-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:07.931827
# Currently retrieving data for california: from 2018-09-01 to 2018-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:09.159597
# Currently retrieving data for california: from 2018-10-01 to 2018-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:10.681312
# Currently retrieving data for california: from 2018-11-01 to 2018-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:12.373903
# Currently retrieving data for california: from 2018-12-01 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:14.999383
# Currently retrieving data for california: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:17.018151
# Currently retrieving data for california: from 2019-02-01 to 2019-02-28
# Time elapsed (hh:mm:ss.ms) 0:01:18.608008
# Currently retrieving data for california: from 2019-03-01 to 2019-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:20.349555
# Currently retrieving data for california: from 2019-04-01 to 2019-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:21.992824
# Currently retrieving data for california: from 2019-05-01 to 2019-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:23.574929
# Currently retrieving data for california: from 2019-06-01 to 2019-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:25.011264
# Currently retrieving data for california: from 2019-07-01 to 2019-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:26.304781
# Currently retrieving data for california: from 2019-08-01 to 2019-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:27.454517
# Currently retrieving data for california: from 2019-09-01 to 2019-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:28.821065
# Currently retrieving data for california: from 2019-10-01 to 2019-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:29.986361
# Currently retrieving data for california: from 2019-11-01 to 2019-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:31.082971
# Currently retrieving data for california: from 2019-12-01 to 2019-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:32.430213
# Currently retrieving data for california: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:33.915503
# Currently retrieving data for california: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:01:35.214477
# Currently retrieving data for california: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:36.667582
# Currently retrieving data for california: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:37.849586
# Currently retrieving data for california: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:39.104641
# Currently retrieving data for california: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:40.266333
# Currently retrieving data for california: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:41.527425
# Currently retrieving data for california: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:42.770270
# Currently retrieving data for california: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:43.866933
# Currently retrieving data for california: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:45.089712
# Currently retrieving data for california: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:46.344473
# Currently retrieving data for california: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:47.698295
# Currently retrieving data for california: from 2021-01-01 to 2021-01-01
# Time elapsed (hh:mm:ss.ms) 0:01:48.111092
#
#
# export california completed!
