# %%
#load pandas
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
CO_df = pd.read_csv('Co Master Data.csv')
type (CO_df)
CO_df.corr()
CO_df.isnull().sum()
# Out:
# Month                      0
# CO_Con                     0
# CO_AQI                     0
# Tot_Petrol_AS              0
# El_Util_Con_Petrol         0
# Indep_Power_Cons_Petrol    0
# Tot_Com_Indus_Petrol       0
# Net_gen_AS                 0
# Net_gen_elec_util          0
# Net_gen_Com/ind            0
# Tot_Flights                0
# Tot_Gas                    0
# Tot_ Ind_ Coal             0
# Jet_Fuel                   0
# GEO_Pl                     0
# NG_Pl                      0
# NUC_Pl                     0
# OBG_Pl                     0
# OT_Pl                      0
# SUN                        0
# WND                        0
# WAT                        0
# dtype: int64

# %%
CO_df.head()
# Out:
#     Month  CO_Con  CO_AQI  Tot_Petrol_AS  El_Util_Con_Petrol  \
# 0  15-Jan   0.746   8.508             11                   5
# 1  15-Feb   0.565   6.442              6                   4
# 2  15-Mar   0.470   5.357              5                   4
# 3  15-Apr   0.362   4.054             10                   5
# 4  15-May   0.285   3.129             48                   5
#
#    Indep_Power_Cons_Petrol  Tot_Com_Indus_Petrol   Net_gen_AS  \
# 0                        5                     0  14246.53253
# 1                        1                     0  12303.54033
# 2                        1                     0  14346.53259
# 3                        5                     0  14568.67886
# 4                       13                    30  15435.01408
#
#    Net_gen_elec_util  Net_gen_Com/ind  ... Tot_ Ind_ Coal  Jet_Fuel  \
# 0            5637.23          1392.17  ...         56.171  6,108.00
# 1            5142.49          1186.70  ...         50.573  6,697.30
# ...

# %%
#correlation heatmap used in order to view correlation between CO_con and all other variables
#pleasant graph just used to get a general grasp on correlations between variables
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(CO_df.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12)
#plt.savefig('Correlation_Heatmap.png', dpi=300, bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
#correlation of one variable (Co_con)
#Data shows Coal consumption is the most highly correlated to CO, everything else is negative
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(CO_df.corr()[['CO_Con']].sort_values(by='CO_Con', ascending=False), 
                      vmin=-1, vmax=1, annot=True, cmap= 'BrBG')
heatmap.set_title('Variables Correlating with CO Concentration', fontdict={'fontsize':18}, pad=16);
#plt.savefig('CO_Con_Correlation_Matrix.png', dpi=300, bbox_inches='tight')

# %%
#general graphs of certain variables with CO_con
sns.relplot(x = 'CO_Con', y = 'Tot_ Ind_ Coal', data = CO_df)
sns.relplot(x = 'CO_Con', y = 'Tot_Gas', data = CO_df)
sns.relplot(x = 'CO_Con', y = 'Net_gen_AS', data = CO_df)
sns.relplot(x = 'CO_Con', y = 'WAT', data = CO_df)

# %%
#linegraph of CO_con over the years (requires a split of month/year columns)
sns.lineplot(x= 'Month', y = 'CO_Con', data = CO_df)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='CO_Con'>

# %%
#dist plot of CO_con
dist = sns.distplot(CO_df['CO_Con'], bins = 10)
dist.set_title ('Dist of CO_Con')
plt.savefig('Dist of CO_Con.png', dpi=300, bbox_inches='tight')
# Out:
# C:\Users\joshu\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
